# %%
import turtle
t=turtle.Turtle()
canh=150
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.goto(0,75)
#hinhfvuong 2
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hinhfvuong 3
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hinhfvuong 4
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hinhfvuong 5
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 6
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 7
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 8
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 9
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 10
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 11
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 12
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 13
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 14
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 15
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 16
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 17
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 18
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 19
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
#hình vuông 20
t.left(18)
t.forward(canh/2)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh/2)
turtle.done()
