# %%
import turtle
t=turtle.Turtle()
canh=200
t.pensize(5)
t.forward(canh)
t.left(90)
t.forward(150)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(150)
t.backward(300)
t.left(90)
t.forward(canh)
t.right(90)
t.forward(150)
t.penup()
t.goto(50,0)
t.pendown()
t.left(180)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
t.penup()
t.goto(0,300)
t.pendown()
t.left(135)
t.forward(140)
t.right(90)
t.forward(140)
t.penup()
t.goto(400,0)
t.pencolor("brown")
t.fillcolor ("brown")
t.begin_fill()
t.pendown()
t.right(45)
t.forward(50)
t.right(90)
t.forward(50)
t.right(90)
t.forward(50)
t.end_fill()
t.pencolor("green")
t.fillcolor ("green")
t.begin_fill()
t.left(90)
t.forward(25)
t.right(135)
t.forward(70)
t.right(90)
t.forward(70)
t.right(135)
t.forward(25)
t.end_fill()
t.penup()
t.goto(300,300)
t.pendown()
t.pencolor("yellow")
t.fillcolor ("yellow")
t.begin_fill()
t.circle(40)
t.end_fill()
t.circle(40)
t.end_fill
turtle.done()
t.left(90)
t.forward(25)
t.right(135)
t.forward(70)
t.right(90)
t.forward(70)
t.right(135)
t.forward(25)
t.penup()
t.goto(300,300)
t.pendown()
t.pencolor("yellow")
t.fillcolor ("yellow")
t.begin_fill()
t.circle (40)
t.end_fill()
t.circle(40)
t.end_fill
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Input In [1], in <cell line: 29>()
#      27 t.goto(0,300)
#      28 t.pendown()
# ---> 29 t.left(135)
#      30 t.forward(140)
#      31 t.right(90)
#
# File ~\anaconda3\lib\turtle.py:1700, in TNavigator.left(self, angle)
#    1681 def left(self, angle):
#    1682     """Turn turtle left by angle units.
#    1683
#    1684     Aliases: left | lt
#    (...)
#    1698     67.0
#    1699     """
# -> 1700     self._rotate(angle)
#
# File ~\anaconda3\lib\turtle.py:3278, in RawTurtle._rotate(self, angle)
#    3276     for _ in range(steps):
#    3277         self._orient = self._orient.rotate(delta)
# -> 3278         self._update()
#    3279 self._orient = neworient
#    3280 self._update()
#
# File ~\anaconda3\lib\turtle.py:2661, in RawTurtle._update(self)
#    2659     return
#    2660 elif screen._tracing == 1:
# ...
