# %%
import turtle
t=turtle.Turtle()
canh=200
t.pensize(5)
t.forward(canh)
t.left(90)
t.forward(150)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(150)
t.backward(300)
t.left(90)
t.forward(canh)
t.right(90)
t.forward(150)
t.penup()
t.goto(50,0)
t.pendown()
t.left(180)
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
t.penup()
t.goto(0,300)
t.pendown()
t.left(135)
t.forward(140)
t.right(90)
t.forward(140)
t.penup()
t.goto(400,0)
t.pencolor("brown")
t.fillcolor ("brown")
t.begin_fill()
t.pendown()
t.right(45)
t.forward(50)
t.right(90)
t.forward(50)
t.right(90)
t.forward(50)
t.end_fill()
t.pencolor("green")
t.fillcolor ("green")
t.begin_fill()
t.left(90)
t.forward(25)
t.right(135)
t.forward(70)
t.right(90)
t.forward(70)
t.right(135)
t.forward(25)
t.end_fill()
t.penup()
t.goto(300,300)
t.pendown()
t.pencolor("yellow")
t.fillcolor ("yellow")
t.begin_fill()
t.circle(40)
t.end_fill()
t.circle(40)
t.end_fill
turtle.done()
t.left(90)
t.forward(25)
t.right(135)
t.forward(70)
t.right(90)
t.forward(70)
t.right(135)
t.forward(25)
t.penup()
t.goto(300,300)
t.pendown()
t.pencolor("yellow")
t.fillcolor ("yellow")
t.begin_fill()
t.circle (40)
t.end_fill()
t.circle(40)
t.end_fill
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Input In [1], in <cell line: 70>()
#      68 t.circle(40)
#      69 t.end_fill()
# ---> 70 t.circle(40)
#      71 t.end_fill
#      72 turtle.done()
#
# File ~\anaconda3\lib\turtle.py:1991, in TNavigator.circle(self, radius, extent, steps)
#    1989 self._rotate(w2)
#    1990 for i in range(steps):
# -> 1991     self.speed(speed)
#    1992     self._go(l)
#    1993     self.speed(0)
#
# File ~\anaconda3\lib\turtle.py:2175, in TPen.speed(self, speed)
#    2173 else:
#    2174     speed = 0
# -> 2175 self.pen(speed=speed)
#
# File ~\anaconda3\lib\turtle.py:2460, in TPen.pen(self, pen, **pendict)
#    2457     sa, ca = math.sin(self._tilt), math.cos(self._tilt)
#    2458     self._shapetrafo = ( scx*ca, scy*(shf*ca + sa),
#    2459                         -scx*sa, scy*(ca - shf*sa))
# -> 2460 self._update()
#
# ...
